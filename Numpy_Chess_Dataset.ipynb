# %% [markdown]
# <a href="https://colab.research.google.com/github/Pooveannan/Python-Projects/blob/main/Numpy_Chess_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cacd1946-c624-4ea8-b6d0-292ea9d5a9f9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cacd1946-c624-4ea8-b6d0-292ea9d5a9f9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
df=pd.read_csv('gdrive/My Drive/chess_game_dataset.csv')
df
# Out:
#              id  rated    created_at  last_move_at  turns victory_status  \
# 0      TZJHLljE  False  1.504210e+12  1.504210e+12   13.0      outoftime
# 1           NaN   True           NaN           NaN   16.0         resign
# 2      mIICvQHh   True  1.504130e+12  1.504130e+12    NaN           mate
# 3           NaN    NaN  1.504110e+12  1.504110e+12   61.0           mate
# 4      9tXo1AUZ   True  1.504030e+12  1.504030e+12   95.0           mate
# ...         ...    ...           ...           ...    ...            ...
# 20053  EfqH7VVH   True           NaN  1.499791e+12    NaN         resign
# 20054  WSJDhbPl   True  1.499698e+12  1.499699e+12    NaN           mate
# 20055  yrAas0Kj   True  1.499698e+12  1.499698e+12    NaN            NaN
# 20056  b0v4tRyF    NaN  1.499696e+12  1.499697e+12    NaN         resign
# 20057  N8G2JHGG   True  1.499643e+12  1.499644e+12   78.0           mate
#
#       winner increment_code       white_id  white_rating            black_id  \
# ...

# %%
df.isnull().sum()
# Out:
# id                3639
# rated             3611
# created_at        3558
# last_move_at      3558
# turns             3636
# victory_status    3567
# winner            3694
# increment_code    3631
# white_id          3646
# white_rating      3713
# black_id          3650
# black_rating      3614
# moves             3713
# opening_eco       3736
# opening_name      3651
# opening_ply       3619
# dtype: int64

# %%
#total rows
len(df)
# Out:
# 20058

# %%
(df.isna().sum()/len(df))*100
# Out:
# id                18.142387
# rated             18.002792
# created_at        17.738558
# last_move_at      17.738558
# turns             18.127430
# victory_status    17.783428
# winner            18.416592
# increment_code    18.102503
# white_id          18.177286
# white_rating      18.511317
# black_id          18.197228
# black_rating      18.017749
# moves             18.511317
# opening_eco       18.625985
# opening_name      18.202214
# opening_ply       18.042676
# dtype: float64

# %%
### 3)
num_col = df.select_dtypes(include= "float64").columns
for col in num_col:
 df[col]=df[col].fillna(df[col].median())
df
# Out:
#              id  rated    created_at  last_move_at  turns victory_status  \
# 0      TZJHLljE  False  1.504210e+12  1.504210e+12   13.0      outoftime
# 1           NaN   True  1.496083e+12  1.496125e+12   16.0         resign
# 2      mIICvQHh   True  1.504130e+12  1.504130e+12   55.0           mate
# 3           NaN    NaN  1.504110e+12  1.504110e+12   61.0           mate
# 4      9tXo1AUZ   True  1.504030e+12  1.504030e+12   95.0           mate
# ...         ...    ...           ...           ...    ...            ...
# 20053  EfqH7VVH   True  1.496083e+12  1.499791e+12   55.0         resign
# 20054  WSJDhbPl   True  1.499698e+12  1.499699e+12   55.0           mate
# 20055  yrAas0Kj   True  1.499698e+12  1.499698e+12   55.0            NaN
# 20056  b0v4tRyF    NaN  1.499696e+12  1.499697e+12   55.0         resign
# 20057  N8G2JHGG   True  1.499643e+12  1.499644e+12   78.0           mate
#
#       winner increment_code       white_id  white_rating            black_id  \
# ...

# %%
## 4) I) checking invalid ratings
import numpy as np
df.loc[(df['white_rating']<=0)|(df['white_rating']>2500),'white_rating']=np.nan
df.isna().sum()
# Out:
# id                3639
# rated             3611
# created_at           0
# last_move_at         0
# turns                0
# victory_status    3567
# winner            3694
# increment_code    3631
# white_id          3646
# white_rating        30
# black_id          3650
# black_rating         0
# moves             3713
# opening_eco       3736
# opening_name      3651
# opening_ply          0
# dtype: int64

# %%
### Results and Winner Standardization

df["winner"].value_counts()
# Out:
# winner
# white    8182
# black    7397
# draw      785
# Name: count, dtype: int64

# %%
df['winner']=df['winner'].str.lower()
df
# Out:
#              id  rated    created_at  last_move_at  turns victory_status  \
# 0      TZJHLljE  False  1.504210e+12  1.504210e+12   13.0      outoftime
# 1           NaN   True  1.496083e+12  1.496125e+12   16.0         resign
# 2      mIICvQHh   True  1.504130e+12  1.504130e+12   55.0           mate
# 3           NaN    NaN  1.504110e+12  1.504110e+12   61.0           mate
# 4      9tXo1AUZ   True  1.504030e+12  1.504030e+12   95.0           mate
# ...         ...    ...           ...           ...    ...            ...
# 20053  EfqH7VVH   True  1.496083e+12  1.499791e+12   55.0         resign
# 20054  WSJDhbPl   True  1.499698e+12  1.499699e+12   55.0           mate
# 20055  yrAas0Kj   True  1.499698e+12  1.499698e+12   55.0            NaN
# 20056  b0v4tRyF    NaN  1.499696e+12  1.499697e+12   55.0         resign
# 20057  N8G2JHGG   True  1.499643e+12  1.499644e+12   78.0           mate
#
#       winner increment_code       white_id  white_rating            black_id  \
# ...
